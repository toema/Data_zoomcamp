# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
pwd
# Out:
# 'C:\\Users\\FLRG0823'

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df=pd.read_csv('green_tripdata_2019-09.csv.gz')
df
# Out:
# C:\Users\FLRG0823\AppData\Local\Temp\ipykernel_20680\680115599.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('green_tripdata_2019-09.csv.gz')
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-09-01 00:10:53   2019-09-01 00:23:46
# 1            2.0  2019-09-01 00:31:22   2019-09-01 00:44:37
# 2            2.0  2019-09-01 00:50:24   2019-09-01 01:03:20
# 3            2.0  2019-09-01 00:27:06   2019-09-01 00:33:22
# 4            2.0  2019-09-01 00:43:23   2019-09-01 00:59:54
# ...          ...                  ...                   ...
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# 449061       NaN  2019-09-30 23:19:00   2019-10-01 00:06:00
# 449062       NaN  2019-09-30 23:35:00   2019-09-30 23:58:00
#
# ...

# %%
df['lpep_pickup_datetime']=pd.to_datetime(df['lpep_pickup_datetime'])
df['lpep_dropoff_datetime']=pd.to_datetime(df['lpep_dropoff_datetime'])

# %%
df.dtypes
# Out:
# VendorID                        float64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %%
df['trip_time']=(df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']).astype('timedelta64[ns]')
df.iloc[df['trip_time'].idxmax()]
# Out:
# VendorID                                 2.0
# lpep_pickup_datetime     2019-09-26 08:58:52
# lpep_dropoff_datetime    2019-09-30 13:43:54
# store_and_fwd_flag                         N
# RatecodeID                              99.0
# PULocationID                             193
# DOLocationID                             193
# passenger_count                          1.0
# trip_distance                            0.0
# fare_amount                              2.5
# extra                                    1.3
# mta_tax                                  0.5
# tip_amount                               0.0
# tolls_amount                             0.0
# ehail_fee                                NaN
# improvement_surcharge                    0.0
# total_amount                             4.3
# payment_type                             2.0
# trip_type                                1.0
# congestion_surcharge                     0.0
# trip_time                    4 days 04:45:02
# ...

# %%
df['total_amount'].nlargest(3).index
df.iloc[df['total_amount'].nlargest(3).index]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 337292       2.0  2019-09-26 19:32:52   2019-09-27 01:50:27
# 35116        2.0  2019-09-04 09:55:07   2019-09-06 14:09:12
# 321679       2.0  2019-09-25 18:04:33   2019-09-26 11:48:28
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 337292                  N         4.0           265            16
# 35116                   N         1.0           193           193
# 321679                  N         1.0           193           193
#
#         passenger_count  trip_distance  fare_amount  ...  mta_tax  tip_amount  \
# 337292              1.0         341.64      1761.00  ...     0.50         0.0
# 35116               1.0           0.30      1600.00  ...     0.50         0.0
# 321679              1.0           0.00       577.81  ...    17.33         0.0
#
#         tolls_amount  ehail_fee  improvement_surcharge  total_amount  \
# 337292           0.0        NaN                    0.3       1762.80
# ...

# %%
df.groupby('PULocationID',as_index=True).agg({'total_amount':['max','sum']
}).sort_values(by=('total_amount','sum'),ascending=False)
# Out:
#              total_amount
#                       max        sum
# PULocationID
# 74                 170.00  553336.48
# 75                 133.05  406348.55
# 41                 134.06  304736.00
# 166                200.00  261491.77
# 82                 330.00  258164.89
# ...                   ...        ...
# 84                  74.24      74.24
# 214                 32.50      73.04
# 172                 68.10      68.10
# 211                 29.00      67.53
# 109                 20.00      41.60
#
# [257 rows x 2 columns]

# %%
df2=pd.read_csv('green_tripdata_2019-09.csv.gz')
df3=pd.read_csv('taxi+_zone_lookup.csv')
# new_df.sort_values('PULocationID')
df4=df3.rename(columns={"LocationID": "PULocationID"})
# df2.info()

df5=df2.merge(df4)
# df5.info()
df5['lpep_pickup_datetime']=pd.to_datetime(df5['lpep_pickup_datetime'])
df5['lpep_dropoff_datetime']=pd.to_datetime(df5['lpep_dropoff_datetime'])
df6=df5.set_index('lpep_pickup_datetime',drop=True)
df6
# Out:
# C:\Users\FLRG0823\AppData\Local\Temp\ipykernel_20680\1543420834.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv('green_tripdata_2019-09.csv.gz')
#                       VendorID lpep_dropoff_datetime store_and_fwd_flag  \
# lpep_pickup_datetime
# 2019-09-01 00:10:53        2.0   2019-09-01 00:23:46                  N
# 2019-09-01 00:10:38        1.0   2019-09-01 00:21:42                  N
# 2019-09-01 00:01:54        2.0   2019-09-01 00:28:59                  N
# 2019-09-01 01:03:23        2.0   2019-09-01 01:12:20                  N
# 2019-09-01 00:53:33        1.0   2019-09-01 01:10:18                  N
# ...                        ...                   ...                ...
# 2019-09-27 18:51:00        NaN   2019-09-27 19:28:00                NaN
# 2019-09-28 16:03:00        NaN   2019-09-28 16:42:00                NaN
# 2019-09-28 20:57:00        NaN   2019-09-28 21:13:00                NaN
# ...

# %%
df7=df6['2019-09-18 00:00:00':'2019-09-19 00:00:00']
df7.groupby('Borough',as_index=True).agg({'total_amount':['max','sum']
}).sort_values(by=('total_amount','sum'),ascending=False)
# Out:
#               total_amount
#                        max       sum
# Borough
# Brooklyn            219.80  96333.24
# Manhattan           136.56  92271.30
# Queens              261.77  78891.01
# Bronx               190.94  32830.09
# Unknown             260.12    728.75
# Staten Island        96.80    342.59

# %%
df8=df3.rename(columns={"LocationID": "DOLocationID"})
# df2.info()

df9=df2.merge(df4)
df9['lpep_pickup_datetime']=pd.to_datetime(df9['lpep_pickup_datetime'])
df9['lpep_dropoff_datetime']=pd.to_datetime(df9['lpep_dropoff_datetime'])
df10=df9.set_index('lpep_pickup_datetime',drop=True)
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 449063 entries, 2019-09-01 00:10:53 to 2019-09-11 14:32:00
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               389920 non-null  float64
#  1   lpep_dropoff_datetime  449063 non-null  datetime64[ns]
#  2   store_and_fwd_flag     389920 non-null  object
#  3   RatecodeID             389920 non-null  float64
#  4   PULocationID           449063 non-null  int64
#  5   DOLocationID           449063 non-null  int64
#  6   passenger_count        389920 non-null  float64
#  7   trip_distance          449063 non-null  float64
#  8   fare_amount            449063 non-null  float64
#  9   extra                  449063 non-null  float64
#  10  mta_tax                449063 non-null  float64
#  11  tip_amount             449063 non-null  float64
#  12  tolls_amount           449063 non-null  float64
# ...

# %%
df11=df6['2019-09-1 00:00:00':'2019-10-1 00:00:00']
df12=df11[df11['PULocationID']==7]
df12.groupby('DOLocationID',as_index=True).agg({'tip_amount':['max','sum']
}).sort_values(by=('tip_amount','max'),ascending=False).head(1)
# Out:
# C:\Users\FLRG0823\AppData\Local\Temp\ipykernel_20680\2086466946.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df11=df6['2019-09-1 00:00:00':'2019-10-1 00:00:00']
#              tip_amount
#                     max     sum
# DOLocationID
# 132               62.31  277.26

# %%
df13=df11[df11['DOLocationID']==132]
df13
# Out:
#                       VendorID lpep_dropoff_datetime store_and_fwd_flag  \
# lpep_pickup_datetime
# 2019-09-01 16:08:36        2.0   2019-09-01 16:50:11                  N
# 2019-09-02 14:11:20        2.0   2019-09-02 15:05:49                  N
# 2019-09-02 15:40:35        2.0   2019-09-02 16:53:09                  N
# 2019-09-06 13:36:30        2.0   2019-09-06 14:30:18                  N
# 2019-09-07 10:18:51        2.0   2019-09-07 10:49:16                  N
# ...                        ...                   ...                ...
# 2019-09-25 18:37:59        2.0   2019-09-25 18:44:04                  N
# 2019-09-28 14:33:05        1.0   2019-09-28 14:43:41                  N
# 2019-09-21 13:48:27        2.0   2019-09-21 14:55:53                  N
# 2019-09-17 05:25:00        NaN   2019-09-17 05:52:00                NaN
# 2019-09-17 16:03:01        2.0   2019-09-17 16:56:39                  N
#
#                       RatecodeID  PULocationID  DOLocationID  passenger_count  \
# ...
